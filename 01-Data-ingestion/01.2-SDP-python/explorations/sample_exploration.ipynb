# %% [markdown]
# ### Example Exploratory Notebook
#
# Use this notebook to explore the data generated by the pipeline in your preferred programming language.
#
# **Note**: This notebook is not executed as part of the pipeline.

# %%
#Explore raw user data

sdf = spark.read.format("json").load("/Volumes/demos/dbdemos_retail_c360/c360/users")
display(sdf)

# %%
#Explore raw order data
sdf = spark.read.format("json").load("/Volumes/demos/dbdemos_retail_c360/c360/orders")
display(sdf)

# %%
#Explore raw event data

sdf = spark.read.format("csv").option("header", True).load("/Volumes/demos/dbdemos_retail_c360/c360/events")
display(sdf)
